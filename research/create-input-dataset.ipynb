# %% [markdown]
# # Create input dataset
#
# ## Rationale:
# We need to generate features at the space level so that we can feed it into a ML model.
#
# ## Methodology:
# We are to preprocess and engineer every datasource to generate features. Then we are to merge all of them so we can use the data for training.
#
# 1. Bureau data
# 2. Credit card features
# 3. Installments features
# 4. POS cash features
# 5. Previous application features
# 6. Main application features
#
# ## Conclusions:
# We ended with a dataset of ``~1,140`` features that will be used for training the model.

# %%
# %load_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd

from functools import reduce

import sys
sys.path.append("../")

# local imports
from preprocess.features.make_features import main as make_full_features
from src.learner_params import target_column
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %%time
# load the datasets
train_df = pd.read_csv("../data/cs-training.csv").rename(columns = {"Unnamed: 0":"Id"})
test_df = pd.read_csv("../data/cs-test.csv").rename(columns = {"Unnamed: 0":"Id"})
# Out:
# CPU times: user 87.3 ms, sys: 41.2 ms, total: 128 ms
# Wall time: 159 ms

# %%
final_df  = make_full_features(train_df, test_df)
# Out:
# 2023-10-09T20:56:04 | INFO | Creating features...
# 2023-10-09T20:56:04 | INFO | Creating model based features...
# Score on test set for fold 1 is :0.645
# Score on test set for fold 2 is :0.566
# Score on test set for fold 3 is :0.703
# Score on test set for fold 1 is :0.837
# Score on test set for fold 2 is :0.84
# Score on test set for fold 3 is :0.845
# Score on test set for fold 1 is :0.856
# Score on test set for fold 2 is :0.859
# Score on test set for fold 3 is :0.862
# 2023-10-09T20:57:54 | INFO | Model based features successfully created.
# 2023-10-09T20:57:58 | INFO | Successfully created featureset of length: 251503 in: 1.90 minutes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 251503 entries, 0 to 251502
# Data columns (total 175 columns):
#  #    Column                                                                        Non-Null Count   Dtype
# ---   ------                                                                        --------------   -----
#  0    Id                                                                            251503 non-null  int64
#  1    SeriousDlqin2yrs                                                              150000 non-null  float64
#  2    RevolvingUtilizationOfUnsecuredLines                                          251503 non-null  float64
#  3    age                                                                           251503 non-null  int64
#  4    NumberOfTime30-59DaysPastDueNotWorse                                          251503 non-null  int64
#  5    DebtRatio                                                                     251503 non-null  float64
#  6    MonthlyIncome                                                                 201669 non-null  float64
#  7    NumberOfOpenCreditLinesAndLoans                                               251503 non-null  int64
#  8    NumberOfTimes90DaysLate                                                       251503 non-null  int64
#  9    NumberRealEstateLoansOrLines                                                  251503 non-null  int64
#  10   NumberOfTime60-89DaysPastDueNotWorse                                          251503 non-null  int64
#  11   NumberOfDependents                                                            244953 non-null  float64
#  12   SumTotalTimesPastDue                                                          251503 non-null  int64
#  13   MeanTotalTimesPastDue                                                         251503 non-null  float64
#  14   StdTotalTimesPastDue                                                          251503 non-null  float64
#  15   MaxTotalTimesPastDue                                                          251503 non-null  int64
#  16   MinTotalTimesPastDue                                                          251503 non-null  int64
#  17   PercentageNumberTimes30to59PastDue                                            51088 non-null   float64
#  18   PercentageNumberTimes60to89PastDue                                            51088 non-null   float64
#  19   PercentageNumberTimes90plusPastDue                                            51088 non-null   float64
#  20   LogDifference30to5960to89                                                     251503 non-null  float64
#  21   LogDifference60to8990plus                                                     251503 non-null  float64
#  22   IncomePerCreditLineLoan                                                       199736 non-null  float64
#  23   IncomePerRealEstateLoan                                                       128796 non-null  float64
#  24   IncomePerDependent                                                            92064 non-null   float64
#  25   IncomePerAge                                                                  201668 non-null  float64
#  26   DependentsPerAge                                                              244952 non-null  float64
#  27   RealEstateLoansPerCreditLineLoan                                              248365 non-null  float64
#  28   UtilizationOverDebtRatio                                                      244615 non-null  float64
#  29   IncomeOverDebtRatio                                                           197526 non-null  float64
#  30   SumTotalTimesPastDuePerCreditLineLoan                                         51088 non-null   float64
#  31   cluster_group                                                                 251503 non-null  int32
#  32   DebtRatio^2                                                                   251503 non-null  float64
#  33   DebtRatio MonthlyIncome                                                       251503 non-null  float64
#  34   DebtRatio NumberOfDependents                                                  251503 non-null  float64
#  35   DebtRatio NumberOfOpenCreditLinesAndLoans                                     251503 non-null  float64
#  36   DebtRatio NumberOfTime30-59DaysPastDueNotWorse                                251503 non-null  float64
#  37   DebtRatio NumberRealEstateLoansOrLines                                        251503 non-null  float64
#  38   DebtRatio RevolvingUtilizationOfUnsecuredLines                                251503 non-null  float64
#  39   DebtRatio age                                                                 251503 non-null  float64
#  40   MonthlyIncome^2                                                               251503 non-null  float64
#  41   MonthlyIncome NumberOfDependents                                              251503 non-null  float64
#  42   MonthlyIncome NumberOfOpenCreditLinesAndLoans                                 251503 non-null  float64
#  43   MonthlyIncome NumberOfTime30-59DaysPastDueNotWorse                            251503 non-null  float64
#  44   MonthlyIncome NumberRealEstateLoansOrLines                                    251503 non-null  float64
#  45   MonthlyIncome RevolvingUtilizationOfUnsecuredLines                            251503 non-null  float64
#  46   MonthlyIncome age                                                             251503 non-null  float64
#  47   NumberOfDependents NumberOfOpenCreditLinesAndLoans                            251503 non-null  float64
#  48   NumberOfDependents RevolvingUtilizationOfUnsecuredLines                       251503 non-null  float64
#  49   NumberOfDependents age                                                        251503 non-null  float64
#  50   NumberOfOpenCreditLinesAndLoans NumberRealEstateLoansOrLines                  251503 non-null  float64
#  51   NumberOfOpenCreditLinesAndLoans RevolvingUtilizationOfUnsecuredLines          251503 non-null  float64
#  52   NumberOfOpenCreditLinesAndLoans age                                           251503 non-null  float64
#  53   NumberOfTime30-59DaysPastDueNotWorse RevolvingUtilizationOfUnsecuredLines     251503 non-null  float64
#  54   NumberOfTime30-59DaysPastDueNotWorse age                                      251503 non-null  float64
#  55   NumberRealEstateLoansOrLines RevolvingUtilizationOfUnsecuredLines             251503 non-null  float64
#  56   NumberRealEstateLoansOrLines age                                              251503 non-null  float64
#  57   RevolvingUtilizationOfUnsecuredLines^2                                        251503 non-null  float64
#  58   RevolvingUtilizationOfUnsecuredLines age                                      251503 non-null  float64
#  59   age^2                                                                         251503 non-null  float64
#  60   prediction_MLPClassifier                                                      251503 non-null  float64
#  61   prediction_RandomForestClassifier                                             251503 non-null  float64
#  62   prediction_AdaBoostClassifier                                                 251503 non-null  float64
#  63   CategoryEncoded_MonthlyIncome_min_DebtRatio                                   199011 non-null  float64
#  64   CategoryEncoded_MonthlyIncome_max_DebtRatio                                   199011 non-null  float64
#  65   CategoryEncoded_MonthlyIncome_mean_DebtRatio                                  199011 non-null  float64
#  66   CategoryEncoded_MonthlyIncome_std_DebtRatio                                   199011 non-null  float64
#  67   CategoryEncoded_MonthlyIncome_min_NumberOfOpenCreditLinesAndLoans             199011 non-null  float64
#  68   CategoryEncoded_MonthlyIncome_max_NumberOfOpenCreditLinesAndLoans             199011 non-null  float64
#  69   CategoryEncoded_MonthlyIncome_mean_NumberOfOpenCreditLinesAndLoans            199011 non-null  float64
#  70   CategoryEncoded_MonthlyIncome_std_NumberOfOpenCreditLinesAndLoans             199011 non-null  float64
#  71   CategoryEncoded_MonthlyIncome_min_NumberOfTime30-59DaysPastDueNotWorse        199011 non-null  float64
#  72   CategoryEncoded_MonthlyIncome_max_NumberOfTime30-59DaysPastDueNotWorse        199011 non-null  float64
#  73   CategoryEncoded_MonthlyIncome_mean_NumberOfTime30-59DaysPastDueNotWorse       199011 non-null  float64
#  74   CategoryEncoded_MonthlyIncome_std_NumberOfTime30-59DaysPastDueNotWorse        199011 non-null  float64
#  75   CategoryEncoded_MonthlyIncome_min_NumberOfTime60-89DaysPastDueNotWorse        199011 non-null  float64
#  76   CategoryEncoded_MonthlyIncome_max_NumberOfTime60-89DaysPastDueNotWorse        199011 non-null  float64
#  77   CategoryEncoded_MonthlyIncome_mean_NumberOfTime60-89DaysPastDueNotWorse       199011 non-null  float64
#  78   CategoryEncoded_MonthlyIncome_std_NumberOfTime60-89DaysPastDueNotWorse        199011 non-null  float64
#  79   CategoryEncoded_MonthlyIncome_min_NumberOfTimes90DaysLate                     199011 non-null  float64
#  80   CategoryEncoded_MonthlyIncome_max_NumberOfTimes90DaysLate                     199011 non-null  float64
#  81   CategoryEncoded_MonthlyIncome_mean_NumberOfTimes90DaysLate                    199011 non-null  float64
#  82   CategoryEncoded_MonthlyIncome_std_NumberOfTimes90DaysLate                     199011 non-null  float64
#  83   CategoryEncoded_MonthlyIncome_min_NumberRealEstateLoansOrLines                199011 non-null  float64
#  84   CategoryEncoded_MonthlyIncome_max_NumberRealEstateLoansOrLines                199011 non-null  float64
#  85   CategoryEncoded_MonthlyIncome_mean_NumberRealEstateLoansOrLines               199011 non-null  float64
#  86   CategoryEncoded_MonthlyIncome_std_NumberRealEstateLoansOrLines                199011 non-null  float64
#  87   CategoryEncoded_MonthlyIncome_min_RevolvingUtilizationOfUnsecuredLines        199011 non-null  float64
#  88   CategoryEncoded_MonthlyIncome_max_RevolvingUtilizationOfUnsecuredLines        199011 non-null  float64
#  89   CategoryEncoded_MonthlyIncome_mean_RevolvingUtilizationOfUnsecuredLines       199011 non-null  float64
#  90   CategoryEncoded_MonthlyIncome_std_RevolvingUtilizationOfUnsecuredLines        199011 non-null  float64
#  91   CategoryEncoded_NumberOfDependents_min_DebtRatio                              99432 non-null   float64
#  92   CategoryEncoded_NumberOfDependents_max_DebtRatio                              99432 non-null   float64
#  93   CategoryEncoded_NumberOfDependents_mean_DebtRatio                             99432 non-null   float64
#  94   CategoryEncoded_NumberOfDependents_std_DebtRatio                              99432 non-null   float64
#  95   CategoryEncoded_NumberOfDependents_min_NumberOfOpenCreditLinesAndLoans        99432 non-null   float64
#  96   CategoryEncoded_NumberOfDependents_max_NumberOfOpenCreditLinesAndLoans        99432 non-null   float64
#  97   CategoryEncoded_NumberOfDependents_mean_NumberOfOpenCreditLinesAndLoans       99432 non-null   float64
#  98   CategoryEncoded_NumberOfDependents_std_NumberOfOpenCreditLinesAndLoans        99432 non-null   float64
#  99   CategoryEncoded_NumberOfDependents_min_NumberOfTime30-59DaysPastDueNotWorse   99432 non-null   float64
#  100  CategoryEncoded_NumberOfDependents_max_NumberOfTime30-59DaysPastDueNotWorse   99432 non-null   float64
#  101  CategoryEncoded_NumberOfDependents_mean_NumberOfTime30-59DaysPastDueNotWorse  99432 non-null   float64
#  102  CategoryEncoded_NumberOfDependents_std_NumberOfTime30-59DaysPastDueNotWorse   99432 non-null   float64
#  103  CategoryEncoded_NumberOfDependents_min_NumberOfTime60-89DaysPastDueNotWorse   99432 non-null   float64
#  104  CategoryEncoded_NumberOfDependents_max_NumberOfTime60-89DaysPastDueNotWorse   99432 non-null   float64
#  105  CategoryEncoded_NumberOfDependents_mean_NumberOfTime60-89DaysPastDueNotWorse  99432 non-null   float64
#  106  CategoryEncoded_NumberOfDependents_std_NumberOfTime60-89DaysPastDueNotWorse   99432 non-null   float64
#  107  CategoryEncoded_NumberOfDependents_min_NumberOfTimes90DaysLate                99432 non-null   float64
#  108  CategoryEncoded_NumberOfDependents_max_NumberOfTimes90DaysLate                99432 non-null   float64
#  109  CategoryEncoded_NumberOfDependents_mean_NumberOfTimes90DaysLate               99432 non-null   float64
#  110  CategoryEncoded_NumberOfDependents_std_NumberOfTimes90DaysLate                99432 non-null   float64
#  111  CategoryEncoded_NumberOfDependents_min_NumberRealEstateLoansOrLines           99432 non-null   float64
#  112  CategoryEncoded_NumberOfDependents_max_NumberRealEstateLoansOrLines           99432 non-null   float64
#  113  CategoryEncoded_NumberOfDependents_mean_NumberRealEstateLoansOrLines          99432 non-null   float64
#  114  CategoryEncoded_NumberOfDependents_std_NumberRealEstateLoansOrLines           99432 non-null   float64
#  115  CategoryEncoded_NumberOfDependents_min_RevolvingUtilizationOfUnsecuredLines   99432 non-null   float64
#  116  CategoryEncoded_NumberOfDependents_max_RevolvingUtilizationOfUnsecuredLines   99432 non-null   float64
#  117  CategoryEncoded_NumberOfDependents_mean_RevolvingUtilizationOfUnsecuredLines  99432 non-null   float64
#  118  CategoryEncoded_NumberOfDependents_std_RevolvingUtilizationOfUnsecuredLines   99432 non-null   float64
#  119  CategoryEncoded_age_min_DebtRatio                                             251502 non-null  float64
#  120  CategoryEncoded_age_max_DebtRatio                                             251502 non-null  float64
#  121  CategoryEncoded_age_mean_DebtRatio                                            251502 non-null  float64
#  122  CategoryEncoded_age_std_DebtRatio                                             251502 non-null  float64
#  123  CategoryEncoded_age_min_NumberOfOpenCreditLinesAndLoans                       251502 non-null  float64
#  124  CategoryEncoded_age_max_NumberOfOpenCreditLinesAndLoans                       251502 non-null  float64
#  125  CategoryEncoded_age_mean_NumberOfOpenCreditLinesAndLoans                      251502 non-null  float64
#  126  CategoryEncoded_age_std_NumberOfOpenCreditLinesAndLoans                       251502 non-null  float64
#  127  CategoryEncoded_age_min_NumberOfTime30-59DaysPastDueNotWorse                  251502 non-null  float64
#  128  CategoryEncoded_age_max_NumberOfTime30-59DaysPastDueNotWorse                  251502 non-null  float64
#  129  CategoryEncoded_age_mean_NumberOfTime30-59DaysPastDueNotWorse                 251502 non-null  float64
#  130  CategoryEncoded_age_std_NumberOfTime30-59DaysPastDueNotWorse                  251502 non-null  float64
#  131  CategoryEncoded_age_min_NumberOfTime60-89DaysPastDueNotWorse                  251502 non-null  float64
#  132  CategoryEncoded_age_max_NumberOfTime60-89DaysPastDueNotWorse                  251502 non-null  float64
#  133  CategoryEncoded_age_mean_NumberOfTime60-89DaysPastDueNotWorse                 251502 non-null  float64
#  134  CategoryEncoded_age_std_NumberOfTime60-89DaysPastDueNotWorse                  251502 non-null  float64
#  135  CategoryEncoded_age_min_NumberOfTimes90DaysLate                               251502 non-null  float64
#  136  CategoryEncoded_age_max_NumberOfTimes90DaysLate                               251502 non-null  float64
#  137  CategoryEncoded_age_mean_NumberOfTimes90DaysLate                              251502 non-null  float64
#  138  CategoryEncoded_age_std_NumberOfTimes90DaysLate                               251502 non-null  float64
#  139  CategoryEncoded_age_min_NumberRealEstateLoansOrLines                          251502 non-null  float64
#  140  CategoryEncoded_age_max_NumberRealEstateLoansOrLines                          251502 non-null  float64
#  141  CategoryEncoded_age_mean_NumberRealEstateLoansOrLines                         251502 non-null  float64
#  142  CategoryEncoded_age_std_NumberRealEstateLoansOrLines                          251502 non-null  float64
#  143  CategoryEncoded_age_min_RevolvingUtilizationOfUnsecuredLines                  251502 non-null  float64
#  144  CategoryEncoded_age_max_RevolvingUtilizationOfUnsecuredLines                  251502 non-null  float64
#  145  CategoryEncoded_age_mean_RevolvingUtilizationOfUnsecuredLines                 251502 non-null  float64
#  146  CategoryEncoded_age_std_RevolvingUtilizationOfUnsecuredLines                  251502 non-null  float64
#  147  CategoryEncoded_cluster_group_min_DebtRatio                                   243538 non-null  float64
#  148  CategoryEncoded_cluster_group_max_DebtRatio                                   243538 non-null  float64
#  149  CategoryEncoded_cluster_group_mean_DebtRatio                                  243538 non-null  float64
#  150  CategoryEncoded_cluster_group_std_DebtRatio                                   243538 non-null  float64
#  151  CategoryEncoded_cluster_group_min_NumberOfOpenCreditLinesAndLoans             243538 non-null  float64
#  152  CategoryEncoded_cluster_group_max_NumberOfOpenCreditLinesAndLoans             243538 non-null  float64
#  153  CategoryEncoded_cluster_group_mean_NumberOfOpenCreditLinesAndLoans            243538 non-null  float64
#  154  CategoryEncoded_cluster_group_std_NumberOfOpenCreditLinesAndLoans             243538 non-null  float64
#  155  CategoryEncoded_cluster_group_min_NumberOfTime30-59DaysPastDueNotWorse        243538 non-null  float64
#  156  CategoryEncoded_cluster_group_max_NumberOfTime30-59DaysPastDueNotWorse        243538 non-null  float64
#  157  CategoryEncoded_cluster_group_mean_NumberOfTime30-59DaysPastDueNotWorse       243538 non-null  float64
#  158  CategoryEncoded_cluster_group_std_NumberOfTime30-59DaysPastDueNotWorse        243538 non-null  float64
#  159  CategoryEncoded_cluster_group_min_NumberOfTime60-89DaysPastDueNotWorse        243538 non-null  float64
#  160  CategoryEncoded_cluster_group_max_NumberOfTime60-89DaysPastDueNotWorse        243538 non-null  float64
#  161  CategoryEncoded_cluster_group_mean_NumberOfTime60-89DaysPastDueNotWorse       243538 non-null  float64
#  162  CategoryEncoded_cluster_group_std_NumberOfTime60-89DaysPastDueNotWorse        243538 non-null  float64
#  163  CategoryEncoded_cluster_group_min_NumberOfTimes90DaysLate                     243538 non-null  float64
#  164  CategoryEncoded_cluster_group_max_NumberOfTimes90DaysLate                     243538 non-null  float64
#  165  CategoryEncoded_cluster_group_mean_NumberOfTimes90DaysLate                    243538 non-null  float64
#  166  CategoryEncoded_cluster_group_std_NumberOfTimes90DaysLate                     243538 non-null  float64
#  167  CategoryEncoded_cluster_group_min_NumberRealEstateLoansOrLines                243538 non-null  float64
#  168  CategoryEncoded_cluster_group_max_NumberRealEstateLoansOrLines                243538 non-null  float64
#  169  CategoryEncoded_cluster_group_mean_NumberRealEstateLoansOrLines               243538 non-null  float64
#  170  CategoryEncoded_cluster_group_std_NumberRealEstateLoansOrLines                243538 non-null  float64
#  171  CategoryEncoded_cluster_group_min_RevolvingUtilizationOfUnsecuredLines        243538 non-null  float64
#  172  CategoryEncoded_cluster_group_max_RevolvingUtilizationOfUnsecuredLines        243538 non-null  float64
#  173  CategoryEncoded_cluster_group_mean_RevolvingUtilizationOfUnsecuredLines       243538 non-null  float64
#  174  CategoryEncoded_cluster_group_std_RevolvingUtilizationOfUnsecuredLines        243538 non-null  float64
# dtypes: float64(164), int32(1), int64(10)
# memory usage: 334.8 MB

# %%
path = "../data/full_dataset_2023-10-07.pkl"
final_df.to_pickle(path)
